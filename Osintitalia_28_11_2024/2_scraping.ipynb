# %% [markdown]
# ### Cosa è il Web Scraping?
# Il web scraping è il processo di estrazione di dati da siti web. Permette di raccogliere informazioni utili che non sono facilmente accessibili in altri formati (come file CSV o API). È uno strumento potente per chi vuole fare storytelling con i dati.
#
#
# ### Avviso
# Prima di iniziare, è importante sapere che:
# - Utilizzare le informazioni raccolte responsabilmente è fondamentale per rispettare la privacy e la proprietà intellettuale.

# %%
# !pip install trafilatura
# Out:
# Requirement already satisfied: trafilatura in /usr/local/lib/python3.10/dist-packages (1.12.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from trafilatura) (2024.8.30)
# Requirement already satisfied: courlan>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (1.3.2)
# Requirement already satisfied: htmldate>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (1.9.2)
# Requirement already satisfied: justext>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (3.0.1)
# Requirement already satisfied: lxml>=5.2.2 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (5.3.0)
# Requirement already satisfied: charset-normalizer>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (2.2.3)
# Requirement already satisfied: babel>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from courlan>=1.2.0->trafilatura) (2.16.0)
# Requirement already satisfied: tld>=0.13 in /usr/local/lib/python3.10/dist-packages (from courlan>=1.2.0->trafilatura) (0.13)
# Requirement already satisfied: dateparser>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from htmldate>=1.8.1->trafilatura) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.9.0.post0 in /usr/local/lib/python3.10/dist-packages (from htmldate>=1.8.1->trafilatura) (2.9.0.post0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.8.1->trafilatura) (2024.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.8.1->trafilatura) (2024.9.11)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.8.1->trafilatura) (5.2)
# Requirement already satisfied: lxml-html-clean in /usr/local/lib/python3.10/dist-packages (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.9.0.post0->htmldate>=1.8.1->trafilatura) (1.16.0)

# %% [markdown]
# # Scraping di un singolo articolo
#
# `trafilatura` è una libreria Python progettata per estrarre il contenuto testuale principale da pagine web, rimuovendo elementi superflui come menu, pubblicità e commenti. È particolarmente utile per analizzare articoli di notizie o blog.

# %%
import trafilatura

# URL dell'articolo
url = "https://www.ansa.it/sito/notizie/sport/tennis/2024/11/25/sinner-universale-come-tomba-e-rossi-simbolo-dellitalianita_f5daf140-cc65-413e-9af4-25b015bba7f2.html"

# Scarica ed estrae il contenuto
downloaded = trafilatura.fetch_url(url)

if downloaded:
    # Estrai il contenuto principale
    article_text = trafilatura.extract(downloaded)

    # Visualizza il risultato
    print("Testo estratto:")
    print(article_text)
else:
    print("Impossibile scaricare il contenuto dall'URL.")
# Out:
# Testo estratto:
# C'è un momento in cui la fama di un campione valica i confini nazionali e lo consacra come star mondiale. E' quello che negli ultimi mesi sta capitando a Jannik Sinner, osannato dai tifosi non più soltanto in Italia ma dagli appassionati di tennis ovunque vada a giocare nel mondo. E se L'Equipe inventa un soprannome per lui (Sinnerminator) significa che quel passaggio è avvenuto. Per essere un campione universale però non basta essere il numero 1 di uno sport, è necessario qualcosa in più.
# Come Valentino Rossi ed Alberto Tomba, il ragazzo di Sesto Pusteria è diventato simbolo dell'italianità. Una nuova italianità. Tomba e Rossi erano accomunati tra loro, seppur a distanza di anni l'uno dall'altro, da una particolare capacità comunicativa accompagnata da gesti irrituali durante e lontano dalle competizioni: un po' "guascone" il bolognese che per primo ha spettacolarizzato lo sci, provocatore il fenomeno di Tavullia che ha trasformato la pista di MotoGp in un "circo" per i media. Sempre sorridenti, amati ma anche odiati, certamente mai anonimi. Sinner è un altro tipo di italiano: freddo, metodico, perfezionista, già concentrato sul prossimo obiettivo. Ma anche pronto a sciogliersi in un sorriso e a gesti di attenzione nei confronti di un raccattapalle o di un avversario. Impassibili anche quanto, come a Montecarlo, subisce una ingiustizia per una svista dell'arbitro.
# Sinner ricorda più un altro azzurro divenuto un idolo internazionale: Yuri Chechi. E' leggenda il gesto con il quale alle Olimpiadi di Atene il nostro "signore degli anelli, alzò platealmente le braccia del bulgaro Jordan Jovčev indicandolo come vincitore dell'oro olimpico in aperta contestazione con gli arbitri che avevano assegnato il primo posto all'atleta di casa. Chechi vinse un bronzo storico (aveva 34 anni ed era reduce da un infortunio che avrebbe messo fine alla carriera di qualsiasi altro atleta) e divenne un paladino dello sport. Non è facile piacere ai tifosi di altre nazioni, soprattutto se c'è rivalità. Ma qualcuno ci è riuscito. Tra gli italiani sicuramente c'è riuscito anche Giacomo Agostini, riconosciuto come il più grande pilota di motociclette di tutti i tempi. Tra i calciatori uno spazio va dedicato a Paolo Maldini e Paolo Rossi. Ma forse l'atleta che più di ogni altro ha fatto innamorare gli sportivi di tutto il mondo è Pietro Mennea: apparentemente esile ma determinatissimo ha fatto entusiasmare generazioni per l'abnegazione nella ricerca della perfezione atletica. Il suo record del mondo sui 200 metri è stato uno dei più longevi della storia dell'atletica: ha resistito 17 anni ma la sua fama è proseguita oltre. Silenzioso, riservato e a tratti schivo, proprio come Sinner. Il ragazzo di Sesto Pusteria ha ancora tanta strada da realizzare ma anche esempi ai quali ispirarsi per non perdersi e continuare a stupire.
# Riproduzione riservata © Copyright ANSA

# %% [markdown]
# # Scraping di un intero sito (semplice) con `ultimate_sitemap_parser`
#
# ### Cos'è una Sitemap?
# Una sitemap è un file XML che elenca tutte le pagine di un sito web. È utilizzata dai motori di ricerca per indicizzare il sito in modo efficiente. Possiamo sfruttare la sitemap per ottenere rapidamente tutte le URL del sito senza dover navigare manualmente attraverso ogni pagina.
#
# ### Cos'è `ultimate_sitemap_parser`?
# `ultimate_sitemap_parser` è una libreria Python che permette di:
# - Scaricare e analizzare la sitemap di un sito web.
# - Estrarre tutte le URL elencate nella sitemap.
# - Gestire sitemaps semplici e complesse.

# %%
# !pip install ultimate_sitemap_parser
# Out:
# Collecting ultimate_sitemap_parser
#   Downloading ultimate_sitemap_parser-0.5-py2.py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from ultimate_sitemap_parser) (2.9.0.post0)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from ultimate_sitemap_parser) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->ultimate_sitemap_parser) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->ultimate_sitemap_parser) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->ultimate_sitemap_parser) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->ultimate_sitemap_parser) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->ultimate_sitemap_parser) (2024.8.30)
# Downloading ultimate_sitemap_parser-0.5-py2.py3-none-any.whl (23 kB)
# Installing collected packages: ultimate_sitemap_parser
# Successfully installed ultimate_sitemap_parser-0.5

# %%
from usp.tree import sitemap_tree_for_homepage
tree = sitemap_tree_for_homepage("https://lefolliedinaruto.wordpress.com/category/manga-naruto/it-IT.sitemap.xml")
# Out:
# 2024-11-27 16:22:05,657 WARNING usp.tree [463/MainThread]: Assuming that the homepage of https://lefolliedinaruto.wordpress.com/category/manga-naruto/it-IT.sitemap.xml is https://lefolliedinaruto.wordpress.com/
# 2024-11-27 16:22:05,661 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/robots.txt...
# 2024-11-27 16:22:05,665 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/robots.txt...
# 2024-11-27 16:22:05,738 INFO usp.fetch_parse [463/MainThread]: Parsing sitemap from URL https://lefolliedinaruto.wordpress.com/robots.txt...
# 2024-11-27 16:22:05,747 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/sitemap.xml...
# 2024-11-27 16:22:05,753 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/sitemap.xml...
# 2024-11-27 16:22:05,812 INFO usp.fetch_parse [463/MainThread]: Parsing sitemap from URL https://lefolliedinaruto.wordpress.com/sitemap.xml...
# 2024-11-27 16:22:05,870 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/news-sitemap.xml...
# 2024-11-27 16:22:05,875 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/news-sitemap.xml...
# 2024-11-27 16:22:06,073 INFO usp.fetch_parse [463/MainThread]: Parsing sitemap from URL https://lefolliedinaruto.wordpress.com/news-sitemap.xml...
# 2024-11-27 16:22:06,078 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/sitemap.xml.gz...
# 2024-11-27 16:22:06,080 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/sitemap.xml.gz...
# 2024-11-27 16:22:06,342 WARNING usp.helpers [463/MainThread]: Request for URL https://lefolliedinaruto.wordpress.com/sitemap.xml.gz failed: 404 Not Found
# 2024-11-27 16:22:06,346 INFO usp.helpers [463/MainThread]: Not retrying for URL https://lefolliedinaruto.wordpress.com/sitemap.xml.gz
# 2024-11-27 16:22:06,348 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/admin/config/search/xmlsitemap...
# 2024-11-27 16:22:06,352 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/admin/config/search/xmlsitemap...
# 2024-11-27 16:22:06,605 WARNING usp.helpers [463/MainThread]: Request for URL https://lefolliedinaruto.wordpress.com/admin/config/search/xmlsitemap failed: 404 Not Found
# 2024-11-27 16:22:06,608 INFO usp.helpers [463/MainThread]: Not retrying for URL https://lefolliedinaruto.wordpress.com/admin/config/search/xmlsitemap
# 2024-11-27 16:22:06,611 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/sitemap_index.xml...
# 2024-11-27 16:22:06,613 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/sitemap_index.xml...
# 2024-11-27 16:22:06,851 WARNING usp.helpers [463/MainThread]: Request for URL https://lefolliedinaruto.wordpress.com/sitemap_index.xml failed: 404 Not Found
# 2024-11-27 16:22:06,853 INFO usp.helpers [463/MainThread]: Not retrying for URL https://lefolliedinaruto.wordpress.com/sitemap_index.xml
# 2024-11-27 16:22:06,855 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/sitemap...
# 2024-11-27 16:22:06,857 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/sitemap...
# 2024-11-27 16:22:07,086 WARNING usp.helpers [463/MainThread]: Request for URL https://lefolliedinaruto.wordpress.com/sitemap failed: 404 Not Found
# 2024-11-27 16:22:07,089 INFO usp.helpers [463/MainThread]: Not retrying for URL https://lefolliedinaruto.wordpress.com/sitemap
# 2024-11-27 16:22:07,100 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/.sitemap.xml...
# 2024-11-27 16:22:07,102 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/.sitemap.xml...
# 2024-11-27 16:22:07,163 WARNING usp.helpers [463/MainThread]: Request for URL https://lefolliedinaruto.wordpress.com/.sitemap.xml failed: 403 Forbidden
# 2024-11-27 16:22:07,164 INFO usp.helpers [463/MainThread]: Not retrying for URL https://lefolliedinaruto.wordpress.com/.sitemap.xml
# 2024-11-27 16:22:07,169 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/sitemap/sitemap-index.xml...
# 2024-11-27 16:22:07,172 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/sitemap/sitemap-index.xml...
# 2024-11-27 16:22:07,408 WARNING usp.helpers [463/MainThread]: Request for URL https://lefolliedinaruto.wordpress.com/sitemap/sitemap-index.xml failed: 404 Not Found
# 2024-11-27 16:22:07,410 INFO usp.helpers [463/MainThread]: Not retrying for URL https://lefolliedinaruto.wordpress.com/sitemap/sitemap-index.xml
# 2024-11-27 16:22:07,413 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/sitemap_index.xml.gz...
# 2024-11-27 16:22:07,416 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/sitemap_index.xml.gz...
# 2024-11-27 16:22:07,661 WARNING usp.helpers [463/MainThread]: Request for URL https://lefolliedinaruto.wordpress.com/sitemap_index.xml.gz failed: 404 Not Found
# 2024-11-27 16:22:07,664 INFO usp.helpers [463/MainThread]: Not retrying for URL https://lefolliedinaruto.wordpress.com/sitemap_index.xml.gz
# 2024-11-27 16:22:07,667 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/sitemap-index.xml.gz...
# 2024-11-27 16:22:07,670 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/sitemap-index.xml.gz...
# 2024-11-27 16:22:07,913 WARNING usp.helpers [463/MainThread]: Request for URL https://lefolliedinaruto.wordpress.com/sitemap-index.xml.gz failed: 404 Not Found
# 2024-11-27 16:22:07,925 INFO usp.helpers [463/MainThread]: Not retrying for URL https://lefolliedinaruto.wordpress.com/sitemap-index.xml.gz
# 2024-11-27 16:22:07,927 INFO usp.fetch_parse [463/MainThread]: Fetching level 0 sitemap from https://lefolliedinaruto.wordpress.com/sitemap-index.xml...
# 2024-11-27 16:22:07,931 INFO usp.helpers [463/MainThread]: Fetching URL https://lefolliedinaruto.wordpress.com/sitemap-index.xml...
# 2024-11-27 16:22:08,174 WARNING usp.helpers [463/MainThread]: Request for URL https://lefolliedinaruto.wordpress.com/sitemap-index.xml failed: 404 Not Found
# 2024-11-27 16:22:08,184 INFO usp.helpers [463/MainThread]: Not retrying for URL https://lefolliedinaruto.wordpress.com/sitemap-index.xml

# %%
import pandas as pd

# Estrai tutte le URL in una lista
url_list = [page.url for page in tree.all_pages()]

# Crea il DataFrame con una sola colonna 'url'
df = pd.DataFrame({'url': url_list})
print(df.shape)
df.head()
# Out:
# (46, 1)
#                                                  url
# 0  https://lefolliedinaruto.wordpress.com/2022/05...
# 1  https://lefolliedinaruto.wordpress.com/2021/01...
# 2  https://lefolliedinaruto.wordpress.com/2019/05...
# 3  https://lefolliedinaruto.wordpress.com/2018/04...
# 4  https://lefolliedinaruto.wordpress.com/2018/03...

# %%
import trafilatura
from tqdm import tqdm

# Funzione per estrarre il testo con Trafilatura
def extract_text(url):
    downloaded = trafilatura.fetch_url(url)
    if downloaded:
        return trafilatura.extract(downloaded)
    else:
        return None  # Nessun testo disponibile


# Configura tqdm per visualizzare il progresso
tqdm.pandas(desc="Processing URLs")

# Applica la funzione di estrazione testo a ogni URL con barra di avanzamento
df['text'] = df['url'].progress_apply(extract_text)

# Visualizza il risultato
display(df.head())
# Out:
# Processing URLs: 100%|██████████| 46/46 [00:12<00:00,  3.77it/s]
#                                                  url  \
# 0  https://lefolliedinaruto.wordpress.com/2022/05...
# 1  https://lefolliedinaruto.wordpress.com/2021/01...
# 2  https://lefolliedinaruto.wordpress.com/2019/05...
# 3  https://lefolliedinaruto.wordpress.com/2018/04...
# 4  https://lefolliedinaruto.wordpress.com/2018/03...
#
#                                                 text
# 0  Introduzione:\nEsistono due emulatori validi: ...
# 1  L’articolo sarà suddiviso nei seguenti punti:\...
# 2  Più che il manga, possiamo dire che è Kishimot...
# 3  (le parole sottolineate contengono link clicca...
# 4  Avevo detto che non avrei più scritto articoli...

# %%
df['text'].iloc[0]
# Out:
# 'Introduzione:\nEsistono due emulatori validi: Duckstation e Beetle PSX HW (Retroarch). Questa guida è per Beetle, a mio parere il migliore, anche se l’emulatore perfetto non esiste…tutt’oggi potreste avere qualche problema con l’emulazione in HD, perciò usate entrambi questi ottimi emulatori…se un gioco non funziona bene su uno, usate l’altro.\nEsempio: Resident Evil 2 su Duckstation riproduce sfondi prerenderizzati con minor qualità di Beetle, mentre per Metal Gear, Duckstation riproduce gli effetti framebuffer meglio di Beetle (difetti cerchiati in rosso).\nLa guida:\nScaricate Retroarch qui, scrollate in basso e cliccate sotto Windows: “Download 64 bit”.\nNon dovete installare niente, scaricherà un archivio che potete estrarre dove volete.\nProcuratevi il bios qui, consiglio sia il giapponese, americano ed europeo. Quindi scaricate: scph5500.bin, scph5501.bin, scph5502.bin.\nRinominateli come li ho scritti, senza maiuscole, e posizionateli nella cartella di Retroarch\\system\\BIOS (se non c’è la cartella BIOS createla).\nAprite il programma, il pad dovrebbe riconoscerlo in automatico, ma vi consiglio di configurarvi i tasti andando in: impostazioni > input > controlli porta 1.\nOra potete caricare i giochi, non tutti i formati delle rom sono compatibili, per PSX è meglio se sono .cue o .ccd, ma se vi serve una guida per convertire i formati fatemelo sapere. Quindi, dal menu principale fate: Carica contenuto > Playlist > Importa contenuto > Scansione directory, dateli la posizione della cartella in cui avete le rom e poi fate “scansiona directory”.\nUna volta finito lo scan, tornate al menu principale e infondo alla colonna vi comparirà l’icona PSX, se ci andate sopra avrete la vostra lista di giochi pronti da lanciare.\nPrima di fare cio, dovete integrare Beetle PSX HW a Retroarch.\nBrevemente: Retroarch può scaricare e avviare molteplici emulatori ed è comodo se siete appassionati di retrogaming e non volete crearvi un sacco di cartelle per emulatori diversi, gestirà tutto Retroarch, vi basta scegliere “Carica core” > “Scarica core” e scegliere dalla lista emulatori quello che cercate, in questo caso “Beetle PSX HW”.\nOra potete lanciare un gioco dalla vostra Playlist, vi chiederà con quale core(emulatore) associarlo, scegliete Beetle e il gioco partirà con le impostazioni base.\nNoi vogliamo cambiarle: cliccate sopra la finestra di Retroarch “command” e poi “menu”.\nIl gioco andrà in pausa, da qui scorrete giù e scegliete “Opzioni”.\nQui dovete cambiare solo 2 cose:\nRenderer: Hardware Vulkan (è il più veloce)\nMetodo accesso CD: Asincrono\nDa qui scorrete su ed entrate in “Video”, copiate queste impostazioni, le altre potete lasciarle come sono.\nRisoluzione potete anche mettere 8x se avete un pc prestante, ma 4x basterà.\nOra tornate nella schermata precedente ed entrate in “Pgxp (precision geometry transform pipeline)”, usate queste impostazioni:\nQuesto serve per eliminare (in parte) il tremolio del 3D classico della PS1, non usate altre impostazioni qui, queste sono le più sicure che non vi daranno glitch grafici.\nAbbiamo quasi finito, tornate nella schermata precedente e questa volta entrate in “Emulazione Hack”, qui potete fare una cosa carina, aumentare il framerate. La PS1 vera è difficile che arrivi a 30 fps stabili, ma con queste impostazioni ci potete arrivare tranquillamente:\nFrequenza CPU Overclock: 150%\nTranquilli, non state overclockando la vostra scheda video, state semplicemente simulando una PS1 più potente del normale. Di standard 150% va bene per tutti i giochi, potete anche settare a 190% in alcuni giochi andrete a toccare i 60 fps, ma non aumentate oltre altrimenti il gioco glitcha, l’audio andrà fuori sync e il gioco andrà a velocità doppia.\nAvete finito. Potete chiudere Retroarch e riaprirlo, lanciare un gioco dalla Playlist e godere delle nuove impostazioni.\nI giochi dovrebbero andarvi lisci, se così non fosse ed avete rallentamenti o l’audio strappa, allora rimettere l’Overclock a 100%, op ...
